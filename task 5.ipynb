# %%
# !pip install networkx
# Out:
# ...
#      ---------------------------------------- 2.0/2.0 MB 46.4 kB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 7.6/7.6 MB 55.5 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.0/1.0 MB 57.2 kB/s eta 0:00:00
# ...
#      -------------------------------------- 98.3/98.3 kB 112.8 kB/s eta 0:00:00
# ...
#      --------------------------------------- 55.3/55.3 kB 44.3 kB/s eta 0:00:00
# ...
#      ------------------------------------- 163.0/163.0 kB 63.5 kB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
graph={
    'S':[('A',2),('B',3),('D',5)],
    'A':[('C',4)],
    'B':[('D',4)],
    'C':[('D',1),('G',2)],
    'D':[('G',5)],
} 

G = nx.Graph()
G.add_nodes_from(graph.keys())

for node in graph:
    for edge in graph[node]:
        G.add_edge(node, edge[0], weight=edge[1])

nx.draw(G, with_labels=True, font_weight='bold')
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()

G.add_nodes_from(['A', 'B', 'C', 'D', 'E'])

G.add_edge('A', 'B')
G.add_edge('B', 'C')
G.add_edge('C', 'D')
G.add_edge('D', 'E')
G.add_edge('E', 'A')

pos = {'A': (0, 1), 'B': (1, 2), 'C': (2, 1), 'D': (1, 0), 'E': (0, 0)}

nx.draw(G, pos, with_labels=True, font_weight='bold')
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create graph object
G = nx.Graph()

# Add nodes to graph
G.add_nodes_from(['Arad', 'Zerind', 'Sibiu', 'Timisoara', 'Oradea', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Rimnicu Vilcea', 'Pitesti', 'Fagaras', 'Bucharest', 'Giurgiu', 'Urziceni', 'Hirsova', 'Vaslui', 'Iasi', 'Neamt', 'Eforie'])

# Add edges to graph
G.add_edges_from([('Arad', 'Zerind'), ('Arad', 'Sibiu'), ('Arad', 'Timisoara'), ('Zerind', 'Oradea'), ('Sibiu', 'Oradea'), ('Sibiu', 'Fagaras'), ('Sibiu', 'Rimnicu Vilcea'), ('Timisoara', 'Lugoj'), ('Lugoj', 'Mehadia'), ('Mehadia', 'Drobeta'), ('Drobeta', 'Craiova'), ('Craiova', 'Rimnicu Vilcea'), ('Rimnicu Vilcea', 'Pitesti'), ('Rimnicu Vilcea', 'Craiova'), ('Pitesti', 'Bucharest'), ('Pitesti', 'Rimnicu Vilcea'), ('Fagaras', 'Bucharest'), ('Bucharest', 'Giurgiu'), ('Bucharest', 'Urziceni'), ('Urziceni', 'Hirsova'), ('Urziceni', 'Vaslui'), ('Hirsova', 'Eforie'), ('Vaslui', 'Iasi'), ('Iasi', 'Neamt')])

# Define positions for nodes
pos = {
    'Arad': (123, 535),
    'Zerind': (75, 450),
    'Sibiu': (245, 468),
    'Timisoara': (30, 390),
    'Oradea': (140, 385),
    'Lugoj': (75, 305),
    'Mehadia': (150, 240),
    'Drobeta': (105, 150),
    'Craiova': (205, 210),
    'Rimnicu Vilcea': (305, 315),
    'Pitesti': (360, 240),
    'Fagaras': (290, 390),
    'Bucharest': (430, 245),
    'Giurgiu': (420, 140),
    'Urziceni': (510, 310),
    'Hirsova': (573, 310),
    'Vaslui': (626, 246),
    'Iasi': (689, 222),
    'Neamt': (733, 156),
    'Eforie': (640, 369)
}

# Draw the graph
nx.draw_networkx_nodes(G, pos, node_size=500, node_color='lightblue')
nx.draw_networkx_edges(G, pos, width=1, alpha=0.8, edge_color='gray')
nx.draw_networkx_labels(G, pos, font_size=10, font_family='sans-serif')
plt.axis('off')
plt.show()
